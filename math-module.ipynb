# %% [markdown]
# <a href="https://www.kaggle.com/code/kalalshivagoud/math-module?scriptVersionId=257270328" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import math

# %% [markdown]
# **constants**

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# **Round off decimals**

# %%
a=3.4   #this will round off to the next high integer
math.ceil(a)
# Out:
# 4

# %%
a=3.4    #this will round off the  next lower integer
math.floor(a)
# Out:
# 3

# %%
a=3.4
math.trunc(a)  #this will remove remove decimal values
# Out:
# 3

# %% [markdown]
# **Exponential &Logarithemic functions**

# %%
x=2    # e to the power of 2
math.exp(x)
# Out:
# 7.38905609893065

# %%
math.log(1000) #by default base is 10
# Out:
# 6.907755278982137

# %% [markdown]
# **Trigonometric functions**

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
degree=90
math.sin(math.radians(degree))
# Out:
# 1.0

# %% [markdown]
# **mathematical**

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.factorial(5)
# Out:
# 120

# %%
l=[1.2,4.3]
sum(l)
math.fsum(l)
# Out:
# 5.5
