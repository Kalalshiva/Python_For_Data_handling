# %% [markdown]
# <a href="https://www.kaggle.com/code/kalalshivagoud/creating-dataframes?scriptVersionId=257268295" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %% [markdown]
# **using list**

# %%
l=['shiva','kalyan','pavan','teja']

# %%
df=pd.DataFrame(l)
df
# Out:
#         0
# 0   shiva
# 1  kalyan
# 2   pavan
# 3    teja

# %% [markdown]
# **using dictionary**

# %%
d={
    'Students':['shiva','kalyan','pavan','teja'],
    'Marks':[12,23,42,13],
    'Age':[16,15,18,20]

}
d
# Out:
# {'Students': ['shiva', 'kalyan', 'pavan', 'teja'],
#  'Marks': [12, 23, 42, 13],
#  'Age': [16, 15, 18, 20]}

# %%
d1=pd.DataFrame(d)
d1
# Out:
#   Students  Marks  Age
# 0    shiva     12   16
# 1   kalyan     23   15
# 2    pavan     42   18
# 3     teja     13   20

# %%
s=pd.Series(d)
s
# Out:
# Students    [shiva, kalyan, pavan, teja]
# Marks                   [12, 23, 42, 13]
# Age                     [16, 15, 18, 20]
# dtype: object
