# %% [markdown]
# <a href="https://www.kaggle.com/code/kalalshivagoud/tuples?scriptVersionId=257276454" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **Tuple vs list**

# %%
  a=() #initializing empty tuple
type(a)
# Out:
# tuple

# %%
t=("tej",2.4,244,"hyd",40)
type(t)
# Out:
# tuple

# %%
t[2]  #indexing
# Out:
# 244

# %%
t[0:4] #slicing
# Out:
# ('tej', 2.4, 244, 'hyd')

# %%
a=("aman",2,[4,3],{"shiva","joy"})
a[3]
# Out:
# {'joy', 'shiva'}

# %%
a[2][0]=5
a[2]
# Out:
# [5, 3]

# %%
a[2][1]="bob"
a[2]
# Out:
# [5, 'bob']

# %% [markdown]
# **Looping in Tuple**

# %%
a
# Out:
# ('aman', 2, [5, 'bob'], {'joy', 'shiva'})

# %%
for i in a:
    print(i)
# Out:
# aman
# 2
# [5, 'bob']
# {'shiva', 'joy'}

# %%
l=len(a)
print(l)
# Out:
# 4

# %%
i=0
while l>0:
    print(a[i])
    i=i+1
    l=l-1
# Out:
# aman
# 2
# [5, 'bob']
# {'shiva', 'joy'}

# %% [markdown]
# **Zip functions**

# %%
L1=["Akshay","priya","pavan"]
L2=[9,5,10]
z=zip(L1,L2)
final_list=list(z)
print(final_list)
# Out:
# [('Akshay', 9), ('priya', 5), ('pavan', 10)]

# %%
for i in final_list:
    print(i)
# Out:
# ('Akshay', 9)
# ('priya', 5)
# ('pavan', 10)

# %% [markdown]
# **methods**

# %%
t1=(1,2,3,4,5,6)
len(t1)
# Out:
# 6

# %%
t2=(7,8,9)
t=t1+t2
print(t)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
max(t)  # results highest number
min(t)  #results lowest number
sum(t)   #adds all the Numbers
t.count(4)  #counts no.of occurances
# Out:
# 1
