# %% [markdown]
# <a href="https://www.kaggle.com/code/kalalshivagoud/series?scriptVersionId=257269283" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/kaggle/input/video-games-sales/video_games_sales.csv")
data
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_sales  eu_sales  jp_sales  \
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
s=pd.read_csv("/kaggle/input/video-games-sales/video_games_sales.csv",usecols=['name'])
s
# Out:
#                                                    name
# 0                                            Wii Sports
# 1                                     Super Mario Bros.
# 2                                        Mario Kart Wii
# 3                                     Wii Sports Resort
# 4                              Pokemon Red/Pokemon Blue
# ...                                                 ...
# 16593                Woody Woodpecker in Crazy Castle 5
# 16594                     Men in Black II: Alien Escape
# 16595  SCORE International Baja 1000: The Official Game
# 16596                                        Know How 2
# 16597                                  Spirits & Spells
#
# [16598 rows x 1 columns]

# %% [markdown]
# **Attrribute of series**

# %%
a={
    'banglore':123,
    'hyd':456,
    'vizag':789
}

# %%
b=pd.Series(a)

# %%
b.values
# Out:
# array([123, 456, 789])

# %%
b.shape
# Out:
# (3,)

# %%
b.dtype
# Out:
# dtype('int64')

# %%
b.index
# Out:
# Index(['banglore', 'hyd', 'vizag'], dtype='object')

# %%
b.is_unique
# Out:
# True

# %%
b.ndim
# Out:
# 1

# %%
b.size
# Out:
# 3

# %% [markdown]
# **Series method documentation**

# %%
s=pd.read_csv("/kaggle/input/video-games-sales/video_games_sales.csv",usecols=['global_sales']).squeeze("columns")
s
# Out:
# 0        82.74
# 1        40.24
# 2        35.82
# 3        33.00
# 4        31.37
#          ...
# 16593     0.01
# 16594     0.01
# 16595     0.01
# 16596     0.01
# 16597     0.01
# Name: global_sales, Length: 16598, dtype: float64

# %%
s.min()
# Out:
# 0.01

# %%
s.max()
# Out:
# 82.74

# %%
s.sum()
# Out:
# 8920.44

# %%
s.prod()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# inf

# %%
s1=pd.Series([-1,3,2])

# %%
s1.prod()
# Out:
# -6

# %%
s1.abs()
# Out:
# 0    1
# 1    3
# 2    2
# dtype: int64

# %%
s1.mean()
# Out:
# 1.3333333333333333

# %%
s1.median()
# Out:
# 2.0

# %%
len(s1)
# Out:
# 3

# %%
s.head()
# Out:
# 0    82.74
# 1    40.24
# 2    35.82
# 3    33.00
# 4    31.37
# Name: global_sales, dtype: float64

# %%
s.tail()
# Out:
# 16593    0.01
# 16594    0.01
# 16595    0.01
# 16596    0.01
# 16597    0.01
# Name: global_sales, dtype: float64

# %%
m=pd.Series([True,True,False])

# %%
m.all() #it will return a true if all the data points are true
# Out:
# False

# %%
m.any() #it will return  true if any one data point is true
# Out:
# True

# %%
m.add_prefix(True)
# Out:
# True0     True
# True1     True
# True2    False
# dtype: bool

# %%
m.add_suffix(True)
# Out:
# 0True     True
# 1True     True
# 2True    False
# dtype: bool
