# %% [markdown]
# <a href="https://www.kaggle.com/code/kalalshivagoud/string-s?scriptVersionId=257259414" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
a= "mathematics"
print(a)
# Out:
# mathematics

# %% [markdown]
# **String Indexing**

# %%
a[5]
# Out:
# 'm'

# %%
len(a)
# Out:
# 11

# %%
a[-1]
# Out:
# 's'

# %% [markdown]
# **String Slicing**

# %%
a[1:9:3]
# Out:
# 'aet'

# %% [markdown]
# splitting

# %%
add = "3-6/1 hyderabad"

# %%
add.find("hyderabad")
# Out:
# 6

# %%
p = "iam learning python course"

# %%
p.split()
# Out:
# ['iam', 'learning', 'python', 'course']

# %%
b="iam-learning-python-course"

# %%
b.split()
# Out:
# ['iam-learning-python-course']

# %%
b.split("-")
# Out:
# ['iam', 'learning', 'python', 'course']

# %% [markdown]
# **Striping a string**- used to remove leading and trailing spaces

# %%
c="finance"
d=" finance "

# %%
c==d
# Out:
# False

# %%
d.strip()
# Out:
# 'finance'

# %%
d= d.strip()

# %%
c==d
# Out:
# True

# %%
name=" shiva "

# %%
name.lstrip()
# Out:
# 'shiva '

# %%
name.rstrip()
# Out:
# ' shiva'

# %% [markdown]
# **inbuilt functions in string**

# %%
a="xyz123"
a.isalnum()
# Out:
# True

# %%
city ="hyderabad"
city.isupper()
# Out:
# False

# %%
city.islower()
# Out:
# True

# %%
city.upper()
# Out:
# 'HYDERABAD'

# %%
city.swapcase()
# Out:
# 'HYDERABAD'

# %%
city.endswith("D")
# Out:
# False

# %% [markdown]
# **looping in strings**

# %%
a=" iam a developer"
for i in a:
    print(i)
# Out:
#
# i
# a
# m
#
# a
#
# d
# e
# v
# e
# l
# o
# p
# e
# r

# %%
a=" iam a developer"
b=a.split()
for i in b:
    print(i)
# Out:
# iam
# a
# developer

# %% [markdown]
# **REVERSING A STRING**

# %%
x="mathematics"
l=len(x)
print(l)
# Out:
# 11

# %%
x[::-1]   #using slicing
# Out:
# 'scitamehtam'

# %%
x="mathematics"        #using loop
r=""
for i in a:
    
    r=i+r
    print(r)
# Out:
#
# i
# ai
# mai
#  mai
# a mai
#  a mai
# d a mai
# ed a mai
# ved a mai
# eved a mai
# leved a mai
# oleved a mai
# poleved a mai
# epoleved a mai
# repoleved a mai

# %%
a="kalyan"
r=""
for i in a:
    r=i+r
print(r)
# Out:
# naylak
