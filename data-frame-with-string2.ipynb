# %% [markdown]
# <a href="https://www.kaggle.com/code/kalalshivagoud/data-frame-with-string2?scriptVersionId=257265878" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
a=pd.read_csv("/kaggle/input/cord-19-eda-parse-json-and-generate-clean-csv/biorxiv_clean.csv",index_col=['title'])

# %%
a.tail()
# Out:
#                                                                                     paper_id  \
# title
# Evaluation of the clinical characteristics of s...  c954675ee859e2f7b8f352a398a67469b50f05de
# Effects of temperature on COVID-19 transmission     8c79b740891714d155a31f1a4fa969f6732fd6ef
# Efficacy of hydroxychloroquine in patients with...  23e7355b5e4e0209f64c9d8d5772092a53b72686
# A Multiscale and Comparative Model for Receptor...  78e49fdb6f0aa9924a5b510341d52b618fff0ca6
# Triphosphates of the Two Components in DESCOVY ...  dea0a7da09689bb89f292e66adaf0188cb4f3a52
#
#                                                                                               authors  \
# title
# Evaluation of the clinical characteristics of s...  Hui Xu, Sufang Huang, Shangkun Liu, Juan Deng,...
# Effects of temperature on COVID-19 transmission                                                   NaN
# ...

# %%
a.reset_index(inplace=True)

# %%
a.head()
# Out:
#                                                title  \
# 0  The Effectiveness of Targeted Quarantine for M...
# 1     Evaluation of Group Testing for SARS-CoV-2 RNA
# 2  Why estimating population-based case fatality ...
# 3  Far-UVC light: A new tool to control the sprea...
# 4  Quantifying SARS-CoV-2 transmission suggests e...
#
#                                    paper_id  \
# 0  bbf09194127619f57b3ddf5daf684593a5831367
# 1  2a21fdd15e07c89c88e8c2f6c6ab5692568876ec
# 2  e686d1ce1540026ecb100c09f99ed091c139b92c
# 3  c6039f8933305c9f44a44c81a15b321b6c2848dc
# 4  073d74442e2655d79b0b3f764a627ec667ad422c
#
#                                              authors  \
# 0             Alastair Jamieson-Lane, Eric Cytrnbaum
# 1  Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
# 2              Lucas Böttcher, Mingtao Xia, Tom Chou
# 3  David Welch, Manuela Buonanno, Veljko Grilj, I...
# 4  Luca Ferretti, Chris Wymant, Michelle Kendall,...
#
# ...

# %%
a.set_index('paper_id',inplace=True)
a.head()
# Out:
#                                                                                       title  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367  The Effectiveness of Targeted Quarantine for M...
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec     Evaluation of Group Testing for SARS-CoV-2 RNA
# e686d1ce1540026ecb100c09f99ed091c139b92c  Why estimating population-based case fatality ...
# c6039f8933305c9f44a44c81a15b321b6c2848dc  Far-UVC light: A new tool to control the sprea...
# 073d74442e2655d79b0b3f764a627ec667ad422c  Quantifying SARS-CoV-2 transmission suggests e...
#
#                                                                                     authors  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367             Alastair Jamieson-Lane, Eric Cytrnbaum
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec  Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
# e686d1ce1540026ecb100c09f99ed091c139b92c              Lucas Böttcher, Mingtao Xia, Tom Chou
# ...

# %%
a.set_index('title',append=True)
# Out:
#                                                                                                                                        authors  \
# paper_id                                 title
# bbf09194127619f57b3ddf5daf684593a5831367 The Effectiveness of Targeted Quarantine for Mi...             Alastair Jamieson-Lane, Eric Cytrnbaum
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec Evaluation of Group Testing for SARS-CoV-2 RNA      Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
# e686d1ce1540026ecb100c09f99ed091c139b92c Why estimating population-based case fatality r...              Lucas Böttcher, Mingtao Xia, Tom Chou
# c6039f8933305c9f44a44c81a15b321b6c2848dc Far-UVC light: A new tool to control the spread...  David Welch, Manuela Buonanno, Veljko Grilj, I...
# 073d74442e2655d79b0b3f764a627ec667ad422c Quantifying SARS-CoV-2 transmission suggests ep...  Luca Ferretti, Chris Wymant, Michelle Kendall,...
# ...

# %%
a.head(3)
# Out:
#                                                                                       title  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367  The Effectiveness of Targeted Quarantine for M...
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec     Evaluation of Group Testing for SARS-CoV-2 RNA
# e686d1ce1540026ecb100c09f99ed091c139b92c  Why estimating population-based case fatality ...
#
#                                                                                     authors  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367             Alastair Jamieson-Lane, Eric Cytrnbaum
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec  Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
# e686d1ce1540026ecb100c09f99ed091c139b92c              Lucas Böttcher, Mingtao Xia, Tom Chou
#
#                                                                                affiliations  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367  Alastair Jamieson-Lane (Carl von Ossietzky Uni...
# ...

# %%
a.set_index('authors',drop=True)
# Out:
#                                                                                                 title  \
# authors
# Alastair Jamieson-Lane, Eric Cytrnbaum              The Effectiveness of Targeted Quarantine for M...
# Nasa Sinnott-Armstrong, Daniel L Klein, Brendan...     Evaluation of Group Testing for SARS-CoV-2 RNA
# Lucas Böttcher, Mingtao Xia, Tom Chou               Why estimating population-based case fatality ...
# David Welch, Manuela Buonanno, Veljko Grilj, Ig...  Far-UVC light: A new tool to control the sprea...
# Luca Ferretti, Chris Wymant, Michelle Kendall, ...  Quantifying SARS-CoV-2 transmission suggests e...
# ...                                                                                               ...
# Hui Xu, Sufang Huang, Shangkun Liu, Juan Deng, ...  Evaluation of the clinical characteristics of ...
# NaN                                                   Effects of temperature on COVID-19 transmission
# ...

# %% [markdown]
# **ACCESING DATA FRAMES**

# %%
a.head()
# Out:
#                                                                                       title  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367  The Effectiveness of Targeted Quarantine for M...
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec     Evaluation of Group Testing for SARS-CoV-2 RNA
# e686d1ce1540026ecb100c09f99ed091c139b92c  Why estimating population-based case fatality ...
# c6039f8933305c9f44a44c81a15b321b6c2848dc  Far-UVC light: A new tool to control the sprea...
# 073d74442e2655d79b0b3f764a627ec667ad422c  Quantifying SARS-CoV-2 transmission suggests e...
#
#                                                                                     authors  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367             Alastair Jamieson-Lane, Eric Cytrnbaum
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec  Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
# e686d1ce1540026ecb100c09f99ed091c139b92c              Lucas Böttcher, Mingtao Xia, Tom Chou
# ...

# %%
a.loc['bbf09194127619f57b3ddf5daf684593a5831367']
# Out:
# title               The Effectiveness of Targeted Quarantine for M...
# authors                        Alastair Jamieson-Lane, Eric Cytrnbaum
# affiliations        Alastair Jamieson-Lane (Carl von Ossietzky Uni...
# abstract            Abstract\n\nWe model the extent to which age t...
# text                Introduction\n\nCOVID-19, initially observed/d...
# bibliography        Impact of non-pharmaceutical interventions (NP...
# raw_authors         [{'first': 'Alastair', 'middle': [], 'last': '...
# raw_bibliography    {'BIBREF0': {'ref_id': 'b0', 'title': 'Impact ...
# Name: bbf09194127619f57b3ddf5daf684593a5831367, dtype: object

# %%
a.loc[['bbf09194127619f57b3ddf5daf684593a5831367','2a21fdd15e07c89c88e8c2f6c6ab5692568876ec']]
# Out:
#                                                                                       title  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367  The Effectiveness of Targeted Quarantine for M...
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec     Evaluation of Group Testing for SARS-CoV-2 RNA
#
#                                                                                     authors  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367             Alastair Jamieson-Lane, Eric Cytrnbaum
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec  Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
#
#                                                                                affiliations  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367  Alastair Jamieson-Lane (Carl von Ossietzky Uni...
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec  Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
#
#                                                                                    abstract  \
# ...

# %% [markdown]
# **Slicing is also possible**

# %%
a.loc['2a21fdd15e07c89c88e8c2f6c6ab5692568876ec':'dea0a7da09689bb89f292e66adaf0188cb4f3a52':2]
# Out:
#                                                                                       title  \
# paper_id
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec     Evaluation of Group Testing for SARS-CoV-2 RNA
# c6039f8933305c9f44a44c81a15b321b6c2848dc  Far-UVC light: A new tool to control the sprea...
# 67a2ae408efcb6686a22ae27435c7e4fa10c4a21  Title: First 12 patients with coronavirus disease
# b5af40bb52bf0b461bbc707777c8d28c6fadcd71  Early chest computed tomography to diagnose CO...
# f33c6d94b0efaa198f8f3f20e644625fa3fe10d2  Sequencing of the human IG light chain loci fr...
# ...                                                                                     ...
# 2e3c753682fba0d9c7a0462051a1287b9599ac92  A comparative multicenter study on the clinica...
# 4dbde66230e386fe4ba89b6dd17382527631964c  FDA approved drugs with broad anti-coronaviral...
# b23ef04fdeffdf21cf7c32a977c96d5b6a2c194c  Multiple-Input Deep Convolutional Neural Netwo...
# ...
